# %% [markdown]
# # **EXPRESSÕES REGULARES(REGEX)**

# %% [markdown]
# - **O que é:** *Uma linguagem compactada e poderosa usada para identificar padrões em strings.*
# - **Propósito:** *Em vez de procurar por textos fixos, o Regex permite buscar "formas" (ex: "um IP", "uma data", "um e-mail"). No contexto de Engenharia de Dados, é vital para transformar logs desestruturados em tabelas organizadas.*

# %% [markdown]
# #### **Importando a biblioteca REGEX**

# %%
import re

# %% [markdown]
# #### 🛠️**Funcionalidades Principais**🛠️

# %% [markdown]
# `re.search()`

# %%
random_text = r"Carlos likes playing some games."

re.search("Carlos", random_text)
# Out:
# <re.Match object; span=(0, 6), match='Carlos'>

# %% [markdown]
# **Deu match! Ou seja, ele achou o padrão "C" "a" "r" "l" "o" "s". O span representa a localização desse padrão, logo, começa-se na posição "0" e termina na "5". Lembre-se que o python "come" um**

# %% [markdown]
# `re.split()`

# %%
random_text = r"Carlos likes playing some games."

re.split("Carlos", random_text)
# Out:
# ['', ' likes playing some games.']

# %% [markdown]
# **Retorna-se uma lista o qual exclui a frase "Carlos" deixando um espaço vazio "".**

# %% [markdown]
# `re.findall()`

# %%
random_text = r"Carlos likes playing some games. Carlos likes eats some foods. Carlos likes study Data Science."

re.findall("Carlos", random_text)
# Out:
# ['Carlos', 'Carlos', 'Carlos']

# %% [markdown]
# **Retorna-se uma lista de todas as ocorrências da frase "Carlos".**

# %% [markdown]
# `re.finditer()`

# %%
import re

random_emails = """carlos123@gmail.com,
maria222@yahoo.com.br,
pedro.araujo@hotmail.com.br,
ana_de_santos@gmail.com"""

pattern = r"""
(?P<username>\w+(?:\.[\w]+)*)
@
(?P<domain>\w+(?:\.[\w]+)*)
\.
(?P<extension>[a-z]*(?:\.[\w]+)*)"""

for email in re.finditer(pattern, random_emails, re.VERBOSE):

    data = email.groupdict()

    print(f"The complete email address is: {email.group(0)}")
    print(f"The Username of Email: {data['username']}")
    print(f"The Domain of Email: {data['domain']}")
    print(f"The Extension of Email: {data['extension']}")
    print("=" * 60)
# Out:
# The complete email address is: carlos123@gmail.com
# The Username of Email: carlos123
# The Domain of Email: gmail
# The Extension of Email: com
# ...
# The complete email address is: maria222@yahoo.com.br
# The Username of Email: maria222
# The Domain of Email: yahoo.com
# The Extension of Email: br
# ...
# The complete email address is: pedro.araujo@hotmail.com.br
# The Username of Email: pedro.araujo
# The Domain of Email: hotmail.com
# The Extension of Email: br
# ...
# The complete email address is: ana_de_santos@gmail.com
# The Username of Email: ana_de_santos
# The Domain of Email: gmail
# The Extension of Email: com
# ...

# %% [markdown]
# **Utilizei o re.finditer() por ser a abordagem mais profissional para extração de dados estruturados. Ele permite que cada componente do e-mail seja acessado por seu nome lógico, transformando texto bruto em dicionários prontos para serem convertidos em tabelas (DataFrames) ou arquivos JSON.**

# %% [markdown]
# **O uso do prefixo r""" aliado à flag re.VERBOSE permite documentar a expressão regular enquanto ela é escrita. Em Regex complexos, isso transforma um código 'ilegível' em uma estrutura modular de fácil manutenção, permitindo o uso de espaços e quebras de linha que são ignorados pelo motor de busca.**

# %% [markdown]
# #### **🚩 Flags (Sinalizadores)**

# %% [markdown]
# - **Conceito:** Flags são parâmetros opcionais que modificam o comportamento das funções de regex. Elas permitem alterar como o padrão é interpretado.

# %% [markdown]
# ##### **1. `re.IGNORECASE` (ou `re.I`)**
# - **Propósito:** Torna a busca insensível a maiúsculas e minúsculas. "Python", "python" e "PYTHON" serão considerados iguais.

# %%
text = "Python is amazing. I love python."

# Sem a flag, encontraria apenas "Python"
print(f"Without flag: {re.findall('Python', text)}")

# Com a flag, encontra "Python" e "python"
print(f"With re.IGNORECASE: {re.findall('Python', text, re.IGNORECASE)}")
# Out:
# Without flag: ['Python']
# With re.IGNORECASE: ['Python', 'python']

# %% [markdown]
# ##### **2. `re.VERBOSE` (ou `re.X`)**
# - **Propósito:** Permite escrever expressões regulares mais legíveis, ignorando espaços em branco e permitindo comentários dentro do padrão. É essencial para regex complexos.
# - **Nota:** Quando essa flag está ativa, espaços literais devem ser escapados (ex: `\ `) ou colocados em um grupo `[ ]`.

# %%
text = "user@example.com"

# Regex complexo escrito de forma legível
pattern = r"""
    ^                   # Começo da string
    [\w\.-]+            # Nome do usuário (letras, números, pontos, traços)
    @                   # O símbolo @
    [\w\.-]+            # Domínio
    $                   # Fim da string
"""

match = re.search(pattern, text, re.VERBOSE)
print(f"Match with re.VERBOSE: {match.group()}")
# Out:
# Match with re.VERBOSE: user@example.com

# %% [markdown]
# #### **🚀 Shortcut Metacharacters (Metacaracteres de Atalho)**

# %% [markdown]
# - **Conceito:** São atalhos para conjuntos comuns de caracteres. Eles tornam o regex mais curto e legível.
# - **`\w` (Word Character):** Corresponde a qualquer caractere alfanumérico (letras, números e sublinhado `_`). Equivalente a `[a-zA-Z0-9_]`.
# - **`\d` (Digit):** Corresponde a qualquer dígito decimal. Equivalente a `[0-9]`.
# - **`\s` (Whitespace):** Corresponde a qualquer caractere de espaço em branco (espaço, tabulação, quebra de linha). Equivalente a `[ \t\n\r\f\v]`.
# - **Nota:** As versões maiúsculas (`\W`, `\D`, `\S`) são a **negação** (tudo que NÃO é word, digit ou whitespace).

# %%
text = "ID: user_01 | Year: 2023"

# Example with \w (Word Character)
# Exemplo com \w (Caractere de Palavra)
# Matches 'user_01', 'Year', etc.
print(f"Word characters: {re.findall(r'\w+', text)}")

# Example with \d (Digit)
# Exemplo com \d (Dígito)
# Matches '01', '2023'
print(f"Digits found: {re.findall(r'\d+', text)}")

# Example with \s (Whitespace)
# Exemplo com \s (Espaço em Branco)
# Splitting by whitespace
# Dividindo por espaço em branco
print(f"Split by whitespace: {re.split(r'\s+', text)}")
# Out:
# Word characters: ['ID', 'user_01', 'Year', '2023']
# Digits found: ['01', '2023']
# Split by whitespace: ['ID:', 'user_01', '|', 'Year:', '2023']

# %% [markdown]
# #### **📦 Sets (Conjuntos) `[]`**

# %% [markdown]
# - **O que são:** Os colchetes `[]` definem um **conjunto de caracteres**. O motor de busca tentará encontrar **um** caractere que esteja dentro desse conjunto.
# - **Exemplos:**
#     - `[abc]`: Procura por "a", "b" OU "c".
#     - `[0-9]`: Procura por qualquer dígito de 0 a 9 (intervalo).
#     - `[a-z]`: Procura por qualquer letra minúscula.
#     - `[^0-9]`: O acento circunflexo `^` dentro do set significa **NEGAÇÃO**. Procura qualquer coisa que **NÃO** seja um dígito.
# - **Nota Importante:** Dentro de um conjunto, a maioria dos metacaracteres (como `.` , `+`, `?`, `*`) **perdem seu poder** e são tratados como caracteres literais. Você não precisa escapá-los com `\`.

# %%
text = "The password is 1234."

# Procurando qualquer dígito
print(f"Digits founded: {re.findall(r'[0-9]', text)}")

# Procurando qualquer coisa que NÃO seja dígito (espaços, letras, pontos)
print(f"No digits: {re.findall(r'[^0-9]', text)}")

# Exemplo com metacaracteres em um set
text_with_metachars = "Find the characters: . + ?"
# O padrão procura pelos caracteres literais '.', '+' ou '?'
print(f"Literal metachars found: {re.findall(r'[.?+]', text_with_metachars)}")
# Out:
# Digits founded: ['1', '2', '3', '4']
# No digits: ['T', 'h', 'e', ' ', 'p', 'a', 's', 's', 'w', 'o', 'r', 'd', ' ', 'i', 's', ' ', '.']
# Literal metachars found: ['.', '+', '?']

# %% [markdown]
# #### **🔢 Quantifiers & Wildcards (Quantificadores e Coringas)**

# %% [markdown]
# - **Conceito:** Definem quantas vezes um caractere ou grupo deve aparecer.
# - **`.` (Ponto):** O "Coringa". Corresponde a **qualquer caractere** (exceto quebra de linha).
# - **`+` (Mais):** Corresponde a **1 ou mais** ocorrências.
# - **`?` (Interrogação):** Corresponde a **0 ou 1** ocorrência (opcional).

# %%
# Exemplo com "." (Ponto) - O Coringa
text = "cat, cut, c@t, c9t"

# c.t corresponde a 'c', qualquer caractere, 't'
print(f"Wildcard matches: {re.findall(r'c.t', text)}")

# Exemplo com + (Mais) - Um ou mais
text_numbers = "abc 12345 def"

# \d+ corresponde a um ou mais dígitos
print(f"Sequence of digits: {re.findall(r'\d+', text_numbers)}")

# Exemplo com "?" (Interrogação) - Opcional
text_color = "color, colour"

# colou?r corresponde a 'colo', 'u' opcional, 'r'
print(f"Optional character: {re.findall(r'colou?r', text_color)}")
# Out:
# Wildcard matches: ['cat', 'cut', 'c@t', 'c9t']
# Sequence of digits: ['12345']
# Optional character: ['color', 'colour']

# %% [markdown]
# #### **⚓ Anchors (Âncoras)**

# %% [markdown]
# - **Conceito:** Âncoras não correspondem a caracteres, mas sim a **posições**. Elas garantem que o padrão seja encontrado no início ou no fim da string.
# - **`^` (Circunflexo):** Corresponde ao **início** da string.
# - **`$` (Cifrão):** Corresponde ao **fim** da string.

# %%
text_1 = "Python is amazing"
text_2 = "I love Python"

# Verificando se começa com "Python"
print(f"Starts with Python? {re.search(r'^Python', text_1)}")
print(f"Starts with Python? {re.search(r'^Python', text_2)}")

# Verificando se termina com "Python"
print(f"Ends with Python? {re.search(r'Python$', text_1)}")
print(f"Ends with Python? {re.search(r'Python$', text_2)}")
# Out:
# Starts with Python? <re.Match object; span=(0, 6), match='Python'>
# Starts with Python? None
# Ends with Python? None
# Ends with Python? <re.Match object; span=(7, 13), match='Python'>

# %% [markdown]
# #### **👥 Grupos `()` e suas Variações**

# %% [markdown]
# - **O que são:** Os parênteses `()` servem para **agrupar** partes da sua expressão regular. Isso permite aplicar quantificadores a uma sequência inteira de caracteres ou extrair partes específicas do texto encontrado.

# %% [markdown]
# ##### **1. Look-Ahead `(?=...)` (Olhar para frente)**
# - **Conceito:** Verifica se o padrão existe logo à frente, mas **não o consome** (não faz parte do match retornado). É como dizer: "Encontre X, mas apenas se X for seguido de Y".

# %%
text = "Carlos likes games. Maria likes food."

# Encontrar nomes (palavras) que são seguidos por "likes"
# O padrão procura uma palavra (\w+) APENAS SE ela for seguida de "likes"
matches = re.findall(r"\w+(?= likes)", text)
print(f"Names Founded (Look-Ahead): {matches}")
# Note que "likes" não aparece no resultado, serviu apenas de condição.
# Out:
# Names Founded (Look-Ahead): ['Carlos', 'Maria']

# %% [markdown]
# ##### **2. Look-Behind `(?<=...)` (Olhar para trás)**
# - **Conceito:** Verifica se o padrão existe logo atrás, mas **não o consome**. É como dizer: "Encontre X, mas apenas se X for precedido por Y".
# - *Nota: O Python exige que o padrão dentro do look-behind tenha tamanho fixo.*

# %%
text = "USD 100, BRL 500, EUR 20"

# Encontrar números precedidos por "USD"
matches = re.findall(r"(?<=USD )\d+", text)
print(f"Dollar Values (Look-Behind): {matches}")
# Out:
# Dollar Values (Look-Behind): ['100']

# %% [markdown]
# ##### **3. Grupo de Não Captura `(?:...)`**
# - **Conceito:** Agrupa os elementos para aplicar lógica (como um `ou` `|` ou repetição), mas **não salva** esse grupo na memória. Isso economiza recursos e limpa os resultados quando você usa `findall` ou `groups`, pois evita retornar subgrupos indesejados.

# %%
text = "banana, bananana"

# Queremos encontrar "bana" seguido de "na" uma ou mais vezes.
# Se usássemos (\w+), o findall retornaria apenas o conteúdo do grupo interno.
# Com (?:...), ele agrupa para o quantificador '+', mas o resultado é a string toda.

matches = re.findall(r"ba(?:na)+", text)
print(f"Groups of no capture: {matches}")
# Out:
# Groups of no capture: ['banana', 'bananana']

# %% [markdown]
# ##### **4. Grupos Nomeados `(?P<nome>...)`**
# - **Conceito:** Em vez de acessar os grupos por índices (1, 2, 3...), você dá um nome a eles. Isso torna o código muito mais legível e fácil de manter, especialmente em regex complexos.
# - *Já vimos um exemplo complexo acima com e-mails, mas aqui vai um exemplo simplificado:*

# %%
text = "Client: Carlos, Idade: 25"

pattern = r"Client: (?P<cliente>\w+), Idade: (?P<idade>\d+)"
match = re.search(pattern, text)

if match:
    print(f"Clients Founded: {match.group('cliente')}")
    print(f"Age Founded: {match.group('idade')}")
# Out:
# Clients Founded: Carlos
# Age Founded: 25

# %% [markdown]
# #### **🔄 Substituição com `re.sub()`**

# %% [markdown]
# - **Conceito:** A função `re.sub(pattern, replacement, string)` é usada para substituir todas as ocorrências de um padrão por um novo texto. É extremamente útil para limpeza de dados.

# %%
text = "The red car and the red bike."

# Substituindo "red" por "blue"
new_text = re.sub(r"red", "blue", text)
print(f"Simple substitution: {new_text}")
# Out:
# Simple substitution: The blue car and the blue bike.

# %% [markdown]
# ##### **Substituição usando Grupos (Backreferences)**
# - **Conceito:** Você pode reutilizar partes do texto original na substituição usando referências aos grupos capturados (`\1`, `\2`, etc.).

# %%
date_text = "2023-10-25"

# Mudando o formato de YYYY-MM-DD para DD/MM/YYYY
# Group 1: Year, Group 2: Month, Group 3: Day
formatted_date = re.sub(r"(\d{4})-(\d{2})-(\d{2})", r"\3/\2/\1", date_text)

print(f"Original Date: {date_text}")
print(f"Formatted Date: {formatted_date}")
# Out:
# Original Date: 2023-10-25
# Formatted Date: 25/10/2023

# %% [markdown]
# #### **🌐 Ferramenta Recomendada: Regex101**
# - **O que é:** Uma ferramenta online interativa para construir, testar e depurar expressões regulares.
# - **Por que usar?**
#     - **Explicação em Tempo Real:** Mostra o que cada parte do seu regex está fazendo.
#     - **Testes Rápidos:** Permite colar seu texto e ver os *matches* instantaneamente.
#     - **Suporte a Python:** Certifique-se de selecionar o "Flavor" (sabor) de Python no menu à esquerda.
# - **Link:** [https://regex101.com/](https://regex101.com/)

# %% [markdown]
# ---
# **Nota:** *Grande parte do conteúdo deste material foi gerado por Inteligência Artificial, porém a idealização, estrutura e organização dos tópicos foram desenvolvidas pelo autor.*
