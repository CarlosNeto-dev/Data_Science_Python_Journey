# %%
import numpy as np
vetor = np.array([1, 2, 3, 4], [5, 6, 7, 8])
print(vetor.ndim)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 import numpy as np
# ----> 2 vetor = np.array([1, 2, 3, 4], [5, 6, 7, 8])
#       3 print(vetor.ndim)
#
# TypeError: Field elements must be 2- or 3-tuples, got '5'
